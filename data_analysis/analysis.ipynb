# %%
# https://data.mendeley.com/datasets/945z9xkc8d/1
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./dataset/Fake or Real News Dataset/test.csv')

# %%
df.head()
# Out:
#                                           text;label
# 0  way pick vps terrible mike penny tim kaine tak...
# 1  obama africa move nairobi president obama prai...
# 2  trump vega phoenix illegals wreak havoc popula...
# 3  obama rare parliamentary window make recess ap...
# 4  climate engineering cryosphere collapse geoeng...

# %%
df['len']= df['title'].apply(lambda x: len(x.split()))

# %%
df['len'].describe()
# Out:
# count    624.000000
# mean       7.931090
# std        4.665029
# min        1.000000
# 25%        5.000000
# 50%        7.000000
# 75%       10.000000
# max       53.000000
# Name: len, dtype: float64
